# %%
import pandas as pd

# mh = pd.read_csv('/content/Mental health Depression disorder Data.csv')
# mh = pd.read_csv('/content/Time Americans Spend Sleeping.csv')
# mh = pd.read_csv('/content/crx.csv')
mh = pd.read_csv('/content/clean_dataset.csv')
mh.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
print(mh.describe)
# Out:
# <bound method NDFrame.describe of      b  30.83       0  u  g   w   v  1.25  t t.1  01  f g.1  00202  0.1  +
# 0    a  58.67   4.460  u  g   q   h  3.04  t   t   6  f   g  00043  560  +
# 1    a  24.50   0.500  u  g   q   h  1.50  t   f   0  f   g  00280  824  +
# 2    b  27.83   1.540  u  g   w   v  3.75  t   t   5  t   g  00100    3  +
# 3    b  20.17   5.625  u  g   w   v  1.71  t   f   0  f   s  00120    0  +
# 4    b  32.08   4.000  u  g   m   v  2.50  t   f   0  t   g  00360    0  +
# ..  ..    ...     ... .. ..  ..  ..   ... ..  ..  .. ..  ..    ...  ... ..
# 684  b  21.08  10.085  y  p   e   h  1.25  f   f   0  f   g  00260    0  -
# 685  a  22.67   0.750  u  g   c   v  2.00  f   t   2  t   g  00200  394  -
# 686  a  25.25  13.500  y  p  ff  ff  2.00  f   t   1  t   g  00200    1  -
# 687  b  17.92   0.205  u  g  aa   v  0.04  f   f   0  f   g  00280  750  -
# 688  b  35.00   3.375  u  g   c   h  8.29  f   f   0  t   g  00000    0  -
#
# [689 rows x 16 columns]>

# %% [markdown]
# Time:
# index, year, avg hrs are quantitative cause they represent either a number or amount, ie. they have numerical meaning
# Period, Error, Type of Days, Age Group, Activity and Sex are qualitative cause they represent categories/kind.
#
# Mental Health:
# Entity and Code are qualitative cause they refer to labels or categories(countries)
# Others are quantitative cause they either represent and index/year or percentage ie - numbers/amounts
#
# Clean_dataset:
# Gender, married, bankcustomer, industry, ethnicity, prior, employed, driverlicense, citizen, zipcode, aproved are qualitative cause they all represent labels, categories or status, even if written as numerical like 'Employed' are, in fact, booleans and numbers represent actual meanings like "Has" or "Doesn't have"
# Others are quantitative as they represent specifically numbers or amounts
